# %% [markdown]
# ## Gather

# %%
import pandas as pd
import zipfile
import requests
import os
import glob
import numpy as np
import requests
import tweepy
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

# %%
df=pd.read_csv("twitter-archive-enhanced.csv")

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Fail
# 2: 892177421306343426
# Fail
# 3: 891815181378084864
# Fail
# 4: 891689557279858688
# Fail
# 5: 891327558926688256
# Fail
# 6: 891087950875897856
# Fail
# 7: 890971913173991426
# Fail
# 8: 890729181411237888
# Fail
# 9: 890609185150312448
# Fail
# 10: 890240255349198849
# Fail
# 11: 890006608113172480
# Fail
# 12: 889880896479866881
# Fail
# 13: 889665388333682689
# Fail
# 14: 889638837579907072
# Fail
# 15: 889531135344209921
# Fail
# 16: 889278841981685760
# Fail
# 17: 888917238123831296
# Fail
# 18: 888804989199671297
# Fail
# 19: 888554962724278272
# Fail
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Fail
# 22: 887705289381826560
# Fail
# 23: 887517139158093824
# Fail
# 24: 887473957103951883
# Fail
# 25: 887343217045368832
# Fail
# 26: 887101392804085760
# Fail
# 27: 886983233522544640
# Fail
# 28: 886736880519319552
# Fail
# 29: 886680336477933568
# Fail
# 30: 886366144734445568
# Fail
# 31: 886267009285017600
# Fail
# ...

# %%
TwitterAE=df.copy() # Thi is to keep the original dataset while making changes to the copy.

# %%
url='https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv';
response = requests.get(url)

# %%
with open(os.path.join(url.split('/')[-1]), mode='wb') as file:
    file.write(response.content)

# %%
predictions= pd.read_csv('image-predictions.tsv', sep='\t')

# %%
TwitterP=predictions.copy()

# %%
tweet=pd.read_json("tweet-json.txt", lines=True)

# %%
TwitterT=tweet.copy()

# %% [markdown]
# # Assess

# %% [markdown]
# ## Visual Assessment

# %%
TwitterAE
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [markdown]
# * Some entries in the expanded_urls column have multiple values, separated by commas.

# %%
TwitterP
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %% [markdown]
# ## Programmatic Assessment

# %%
TwitterAE.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
TwitterAE.describe(include='all')
# Out:
#             tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count   2.356000e+03           7.800000e+01         7.800000e+01
# unique           NaN                    NaN                  NaN
# top              NaN                    NaN                  NaN
# freq             NaN                    NaN                  NaN
# mean    7.427716e+17           7.455079e+17         2.014171e+16
# std     6.856705e+16           7.582492e+16         1.252797e+17
# min     6.660209e+17           6.658147e+17         1.185634e+07
# 25%     6.783989e+17           6.757419e+17         3.086374e+08
# 50%     7.196279e+17           7.038708e+17         4.196984e+09
# 75%     7.993373e+17           8.257804e+17         4.196984e+09
# max     8.924206e+17           8.862664e+17         8.405479e+17
#
#                         timestamp  \
# count                        2356
# unique                       2356
# top     2016-02-08 17:17:22 +0000
# freq                            1
# ...

# %%
TwitterT.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1           NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2           NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3           NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4           NaN          NaN 2017-07-29 16:00:24           [0, 138]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           39467
# 1  {'media': [{'id': 892177413194625024, 'id_str'...           33819
# ...

# %%
TwitterT.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'favorite_count', 'favorited',
#        'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
#        'lang', 'place', 'possibly_sensitive', 'possibly_sensitive_appealable',
#        'quoted_status', 'quoted_status_id', 'quoted_status_id_str',
#        'retweet_count', 'retweeted', 'retweeted_status', 'source', 'truncated',
#        'user'],
#       dtype='object')

# %% [markdown]
# * Part of the requirements is to only include favorite_count and retweet_count in this dataset.

# %%
TwitterAE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# * Timestamp should be datetime
# * Retweeted_status_timestamp should be datetime

# %%
TwitterAE['expanded_urls']
# Out:
# 0       https://twitter.com/dog_rates/status/892420643...
# 1       https://twitter.com/dog_rates/status/892177421...
# 2       https://twitter.com/dog_rates/status/891815181...
# 3       https://twitter.com/dog_rates/status/891689557...
# 4       https://twitter.com/dog_rates/status/891327558...
# 5       https://twitter.com/dog_rates/status/891087950...
# 6       https://gofundme.com/ydvmve-surgery-for-jax,ht...
# 7       https://twitter.com/dog_rates/status/890729181...
# 8       https://twitter.com/dog_rates/status/890609185...
# 9       https://twitter.com/dog_rates/status/890240255...
# 10      https://twitter.com/dog_rates/status/890006608...
# 11      https://twitter.com/dog_rates/status/889880896...
# 12      https://twitter.com/dog_rates/status/889665388...
# 13      https://twitter.com/dog_rates/status/889638837...
# 14      https://twitter.com/dog_rates/status/889531135...
# 15      https://twitter.com/dog_rates/status/889278841...
# ...

# %% [markdown]
# * This is a confirmation that some entries in the expanded_urls column have multiple values, separated by commas.

# %%
TwitterAE['name'].value_counts()
# Out:
# None         745
# a             55
# Charlie       12
# Oliver        11
# Lucy          11
# Cooper        11
# Tucker        10
# Lola          10
# Penny         10
# Bo             9
# Winston        9
# the            8
# Sadie          8
# an             7
# Daisy          7
# Buddy          7
# Toby           7
# Bailey         7
# Dave           6
# Scout          6
# Rusty          6
# Milo           6
# Oscar          6
# Stanley        6
# Jax            6
# Bella          6
# Jack           6
# Koda           6
# Leo            6
# very           5
#             ...
# Ralphy         1
# Winifred       1
# Kara           1
# Stewie         1
# Chesney        1
# Chubbs         1
# Kendall        1
# Hazel          1
# Samsom         1
# Dunkin         1
# Brat           1
# Schnitzel      1
# Mauve          1
# Chadrick       1
# Kanu           1
# Kody           1
# Jarod          1
# Emanuel        1
# Clifford       1
# Peanut         1
# Goose          1
# ...

# %% [markdown]
# * Some of the entries in the name column are incorrect. For example, "a", "the", "an" are cases where the text include "this is a", "this is the" and "this is an" respectively.

# %%
TwitterAE['name'].sort_values()
# Out:
# 1035            Abby
# 1021            Abby
# 938              Ace
# 1933            Acro
# 1327           Adele
# 1934           Aiden
# 77               Aja
# 480            Akumi
# 820               Al
# 875           Albert
# 1954          Albert
# 144            Albus
# 412            Albus
# 1115         Aldrick
# 2046       Alejandro
# 374        Alexander
# 1189    Alexanderson
# 486              Alf
# 2238           Alfie
# 661            Alfie
# 367            Alfie
# 1616           Alfie
# 858            Alfie
# 51              Alfy
# 201            Alice
# 1701           Alice
# 1495           Amber
# 1334         Ambrose
# 2078             Amy
# 2195          Amélie
#             ...
# 852               my
# 988              not
# 335              not
# 1747      officially
# 1206             old
# 993              one
# 1936             one
# 924              one
# 369              one
# 2326           quite
# 169            quite
# 118            quite
# ...

# %% [markdown]
# * This shows more errors in the name column like "very", "unacceptable", "such", "quite", "officially", "not", "my" and so on.
# * Some name values start with capital letters while some don't

# %%
TwitterT.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1           NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2           NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3           NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4           NaN          NaN 2017-07-29 16:00:24           [0, 138]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           39467
# 1  {'media': [{'id': 892177413194625024, 'id_str'...           33819
# ...

# %% [markdown]
# * The  display_text_range should be broken down to display_text_minimum and display_text_maximum

# %%
TwitterAE.expanded_urls.value_counts()
# Out:
# https://twitter.com/dog_rates/status/673295268553605120/photo/1                                                                                                                                                                                                                                              2
# https://www.gofundme.com/3ti3nps,https://twitter.com/dog_rates/status/868552278524837888/photo/1,https://twitter.com/dog_rates/status/868552278524837888/photo/1                                                                                                                                             2
# https://twitter.com/dog_rates/status/761672994376806400/video/1                                                                                                                                                                                                                                              2
# ...

# %% [markdown]
# * Some entries in the expanded_urls column are duplicates.

# %%
TwitterAE[~TwitterAE['retweeted_status_id'].isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# 74    878316110768087041                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 91    874434818259525634                    NaN                  NaN
# 95    873697596434513921                    NaN                  NaN
# 97    873337748698140672                    NaN                  NaN
# 101   872668790621863937                    NaN                  NaN
# 109   871166179821445120                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# ...

# %% [markdown]
# * Some of the tweets are retweents having retweeted_status_id that is not null

# %%
TwitterP.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
TwitterP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
TwitterP.describe(include='all')
# Out:
#             tweet_id                                          jpg_url  \
# count   2.075000e+03                                             2075
# unique           NaN                                             2009
# top              NaN  https://pbs.twimg.com/media/Cx5R8wPVEAALa9r.jpg
# freq             NaN                                                2
# mean    7.384514e+17                                              NaN
# std     6.785203e+16                                              NaN
# min     6.660209e+17                                              NaN
# 25%     6.764835e+17                                              NaN
# 50%     7.119988e+17                                              NaN
# 75%     7.932034e+17                                              NaN
# max     8.924206e+17                                              NaN
#
#             img_num                p1      p1_conf p1_dog                  p2  \
# ...

# %%
TwitterP['jpg_url'].value_counts()
# Out:
# https://pbs.twimg.com/media/Cx5R8wPVEAALa9r.jpg                                            2
# https://pbs.twimg.com/media/CsGnz64WYAEIDHJ.jpg                                            2
# https://pbs.twimg.com/media/Ct72q9jWcAAhlnw.jpg                                            2
# https://pbs.twimg.com/media/CVMOlMiWwAA4Yxl.jpg                                            2
# https://pbs.twimg.com/media/CpmyNumW8AAAJGj.jpg                                            2
# https://pbs.twimg.com/media/C4bTH6nWMAAX_bJ.jpg                                            2
# https://pbs.twimg.com/media/CwiuEJmW8AAZnit.jpg                                            2
# https://pbs.twimg.com/media/Cwx99rpW8AMk_Ie.jpg                                            2
# https://pbs.twimg.com/media/Cbs3DOAXIAAp3Bd.jpg                                            2
# https://pbs.twimg.com/media/DA7iHL5U0AA1OQo.jpg                                            2
# ...

# %% [markdown]
# * The prediction dataset (TwitterP) has duplicates

# %% [markdown]
# ## Summary of Quality Issues found
# 1. Some expanded_urls contain duplicate urls, separated by commas.
# 2. Timestamp and Retweeted_status_timestamp  should be datetime
# 3. Some records have space before expanded urls
# 4. Some name entries are incorrect.
# 5. Name is sometimes caipitalized and other times not.
# 6. Some of the tweets are retweet
# 7. There are duplicates in expanded-urls columns
# 8. Prediction dataset has duplicates.
#
# ## Summary of Tidiness Issues found
# 1. The display_text_range in TwitterT should be broken down to display_text_minimum and display_text_maximum.
# 2. Twitter archive (TwitterAE) and the prediction (TwitterP) datasets should be one dataset.

# %% [markdown]
# # Clean

# %% [markdown]
# #### Define Quality
# 1. Split expanded_urls containing repeated urls, separated by commas. Leave only one url in the field.
# 2. Convert Timestamp and Retweeted_status_timestamp to datetime
# 3. Remove space before some expanded_urls
# 4. Replace incorrect name entries with "None".
# 5. Caipitalized the first letter of each name.
# 6. Remove retweets
# 7. Remove duplicates expanded_urls columns
# 8. Remove duplicates from the prediction dataset.
#
# #### Define Tidiness
# 1. Break down display_text_range in TwitterT into display_text_minimum and display_text_maximum.
# 2. Merge Twitter archive (TwitterAE) and the prediction (TwitterP) datasets on tweet_id.

# %% [markdown]
# ## Cleaning Quality Issues Found

# %% [markdown]
# 1. Some expanded_urls contain duplicate urls, separated by commas.

# %%
TwitterAE[TwitterAE['expanded_urls'].str.contains(",")==True]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 4     891327558926688256                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 13    889638837579907072                    NaN                  NaN
# 17    888804989199671297                    NaN                  NaN
# 18    888554962724278272                    NaN                  NaN
# 19    888202515573088257                    NaN                  NaN
# 20    888078434458587136                    NaN                  NaN
# 23    887473957103951883                    NaN                  NaN
# 26    886983233522544640                    NaN                  NaN
# 27    886736880519319552                    NaN                  NaN
# 29    886366144734445568                    NaN                  NaN
# ...

# %%
new = TwitterAE["expanded_urls"].str.split(",", n = 1, expand = True) 
TwitterAE["expanded_urls"]= new[0]

# %% [markdown]
# 2a. Timestamp should be datetime

# %%
TwitterAE['timestamp']=pd.to_datetime(TwitterAE['timestamp'])

# %% [markdown]
# 2b. Retweeted_status_timestamp should be datetime

# %%
TwitterAE['retweeted_status_timestamp']=pd.to_datetime(TwitterAE['retweeted_status_timestamp'])

# %% [markdown]
# 3. Some records have space before expanded urls

# %%
TwitterAE["expanded_urls"]=TwitterAE["expanded_urls"].str.strip()

# %% [markdown]
# 4. Whenever text start with This is the, the name is incorrect.

# %%
TwitterAE.name
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
# 5           None
# 6            Jax
# 7           None
# 8           Zoey
# 9         Cassie
# 10          Koda
# 11         Bruno
# 12          None
# 13           Ted
# 14        Stuart
# 15        Oliver
# 16           Jim
# 17          Zeke
# 18       Ralphus
# 19        Canela
# 20        Gerald
# 21       Jeffrey
# 22          such
# 23        Canela
# 24          None
# 25          None
# 26          Maya
# 27        Mingus
# 28         Derek
# 29        Roscoe
#           ...
# 2326       quite
# 2327           a
# 2328        None
# 2329        None
# 2330        None
# 2331        None
# 2332        None
# 2333          an
# 2334           a
# 2335          an
# 2336        None
# 2337        None
# 2338        None
# 2339        None
# 2340        None
# 2341        None
# 2342        None
# 2343        None
# 2344        None
# 2345         the
# 2346         the
# ...

# %%
TwitterAE['name']=TwitterAE['name'].str.replace('the','None')

# %%
TwitterAE['name']=TwitterAE['name'].str.replace('a','None')

# %%
TwitterAE['name']=TwitterAE['name'].str.replace('an','None')

# %%
TwitterAE['name']=TwitterAE['name'].str.replace('such','None')

# %% [markdown]
# 5. Name is sometimes caipitalized and other times not.

# %%
TwitterAE['name']=TwitterAE['name'].str.capitalize

# %% [markdown]
# 6. Some of the tweets are retweet. Remove them

# %%
TwitterAE=TwitterAE[TwitterAE['retweeted_status_id'].isnull()]

# %% [markdown]
# 7. There are duplicates in expanded-urls columns

# %%
TwitterAE.drop_duplicates(subset ="expanded_urls",keep=False, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# 8. Prediction dataset has duplicates.

# %%
#drop duplicates
TwitterP.drop_duplicates(subset ="jpg_url", 
                     keep = False, inplace = True)

# %% [markdown]
# #### Test Quality

# %%
# 1.
TwitterAE[TwitterAE['expanded_urls'].str.contains(",")==True]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# 2a
TwitterAE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2115 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2115 non-null int64
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     2115 non-null datetime64[ns]
# source                        2115 non-null object
# text                          2115 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null datetime64[ns]
# expanded_urls                 2115 non-null object
# rating_numerator              2115 non-null int64
# rating_denominator            2115 non-null int64
# name                          2115 non-null object
# doggo                         2115 non-null object
# floofer                       2115 non-null object
# pupper                        2115 non-null object
# ...

# %%
# 3
TwitterAE["expanded_urls"].head()
# Out:
# 0    https://twitter.com/dog_rates/status/892420643...
# 1    https://twitter.com/dog_rates/status/892177421...
# 2    https://twitter.com/dog_rates/status/891815181...
# 3    https://twitter.com/dog_rates/status/891689557...
# 4    https://twitter.com/dog_rates/status/891327558...
# Name: expanded_urls, dtype: object

# %%
# 4 and 5
TwitterAE['name'].value_counts()
# Out:
# <bound method _noarg_wrapper.<locals>.wrapper of <pandas.core.strings.StringMethods object at 0x7fab83d3de80>>    2115
# Name: name, dtype: int64

# %%
# 6
TwitterAE[TwitterAE['text'].str.contains('RT @', regex=False)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# 7
TwitterAE[TwitterAE['expanded_urls'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# 8
TwitterP[TwitterP['jpg_url'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %% [markdown]
# # Cleaning Tidiness Issues

# %% [markdown]
# * Break down display_text_range in TwitterT into display_text_minimum and display_text_maximum.

# %%
TwitterT['display_text_range'].head(5)
# Out:
# 0     [0, 85]
# 1    [0, 138]
# 2    [0, 121]
# 3     [0, 79]
# 4    [0, 138]
# Name: display_text_range, dtype: object

# %%
TwitterT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
# contributors                     0 non-null float64
# coordinates                      0 non-null float64
# created_at                       2354 non-null datetime64[ns]
# display_text_range               2354 non-null object
# entities                         2354 non-null object
# extended_entities                2073 non-null object
# favorite_count                   2354 non-null int64
# favorited                        2354 non-null bool
# full_text                        2354 non-null object
# geo                              0 non-null float64
# id                               2354 non-null int64
# id_str                           2354 non-null int64
# in_reply_to_screen_name          78 non-null object
# in_reply_to_status_id            78 non-null float64
# in_reply_to_status_id_str        78 non-null float64
# ...

# %%
TwitterTN=TwitterT['display_text_range'].str.slice(0,1)
TwitterTNT=TwitterT['display_text_range']
NewColumns=pd.DataFrame(TwitterT.display_text_range.values.tolist(), index= TwitterT.index)
TwitterT['display_text_minimum']=New[0]
TwitterT['display_text_maximum']=New[1]
TwitterT=TwitterT.drop(['display_text_range'], axis=1)

# %% [markdown]
# ##### Test

# %%
TwitterT
# Out:
#       contributors  coordinates          created_at  \
# 0              NaN          NaN 2017-08-01 16:23:56
# 1              NaN          NaN 2017-08-01 00:17:27
# 2              NaN          NaN 2017-07-31 00:18:03
# 3              NaN          NaN 2017-07-30 15:58:51
# 4              NaN          NaN 2017-07-29 16:00:24
# 5              NaN          NaN 2017-07-29 00:08:17
# 6              NaN          NaN 2017-07-28 16:27:12
# 7              NaN          NaN 2017-07-28 00:22:40
# 8              NaN          NaN 2017-07-27 16:25:51
# 9              NaN          NaN 2017-07-26 15:59:51
# 10             NaN          NaN 2017-07-26 00:31:25
# 11             NaN          NaN 2017-07-25 16:11:53
# 12             NaN          NaN 2017-07-25 01:55:32
# 13             NaN          NaN 2017-07-25 00:10:02
# 14             NaN          NaN 2017-07-24 17:02:04
# 15             NaN          NaN 2017-07-24 00:19:32
# 16             NaN          NaN 2017-07-23 00:22:39
# ...

# %% [markdown]
# * Merge Twitter archive (TwitterAE) and the prediction (TwitterP) datasets on tweet_id.

# %%
TwitterAM=TwitterAE.merge(TwitterP, left_on ='tweet_id', right_on='tweet_id')

# %% [markdown]
# #### Test

# %%
TwitterAM.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %% [markdown]
# Now, I will save the new files.

# %%
TwitterAM.to_csv('twitter_archive_master.csv')

# %%
TwitterT.to_csv('twitter_archive_retweet.csv')

# %%
TwitterT.plot(x='retweet_count', y='favorite_count', kind='scatter')

# %%
TwitterAM.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#             timestamp                                             source  \
# 0 2017-08-01 16:23:56  <a href="http://twitter.com/download/iphone" r...
# 1 2017-08-01 00:17:27  <a href="http://twitter.com/download/iphone" r...
# 2 2017-07-31 00:18:03  <a href="http://twitter.com/download/iphone" r...
# 3 2017-07-30 15:58:51  <a href="http://twitter.com/download/iphone" r...
# 4 2017-07-29 16:00:24  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# ...

# %%
sorted_stage = TwitterAM['p1'].value_counts().head(5).index
sns.set(style="darkgrid")
sns.countplot(data = TwitterAM, x = 'p1', order = sorted_stage, orient = 'h')
plt.xticks(rotation = 360)
#a4_dims = (20, 20)
sns.set(rc={'figure.figsize':(5,10)})
plt.xlabel('#1 prediction', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('The Distribution of #1 prediction',fontsize=30)
# Out:
# Text(0.5,1,'The Distribution of #1 prediction')

# %%
sorted_stage = TwitterAM['p2'].value_counts().head(5).index
sns.set(style="darkgrid")
sns.countplot(data = TwitterAM, x = 'p2', order = sorted_stage, orient = 'h')
plt.xticks(rotation = 360)
#a4_dims = (20, 20)
sns.set(rc={'figure.figsize':(5,10)})
plt.xlabel('#2 prediction', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('The Distribution of #2 prediction',fontsize=30)
# Out:
# Text(0.5,1,'The Distribution of #2 prediction')

# %%
sorted_stage = TwitterAM['p3'].value_counts().head(5).index
sns.set(style="darkgrid")
sns.countplot(data = TwitterAM, x = 'p3', order = sorted_stage, orient = 'h')
plt.xticks(rotation = 360)
#a4_dims = (20, 20)
sns.set(rc={'figure.figsize':(5,10)})
plt.xlabel('#3 prediction', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('The Distribution of #3 prediction',fontsize=30)
# Out:
# Text(0.5,1,'The Distribution of #3 prediction')

# %% [markdown]
# Insights:
#     1. Golden Retriever has the highest #1 prediction, followed by Labrador retriever.
#     2. Golden Retriever and Labrador Retriever are in the top 5 for the #1 prediction, #2 prediction and #3 prediction.
#     3. Only Golden Retriever was predicted for more than 100 dogs as a #1, #2 or #3 prediction.

# %%
tweet.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'favorite_count', 'favorited',
#        'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
#        'lang', 'place', 'possibly_sensitive', 'possibly_sensitive_appealable',
#        'quoted_status', 'quoted_status_id', 'quoted_status_id_str',
#        'retweet_count', 'retweeted', 'retweeted_status', 'source', 'truncated',
#        'user'],
#       dtype='object')
